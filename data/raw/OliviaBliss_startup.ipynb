# %%
import pandas as pd
sd = pd.read_csv("startup_funding_csv.csv").sort_values(by=["Sr No"])
sd
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1          9/1/20                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3          9/1/20                     Mamaearth
# 3         4          2/1/20  https://www.wealthbucket.in/
# 4         5          2/1/20                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
subset = sd[["Startup Name", "Industry Vertical", "City  Location", "InvestmentnType", "Amount in USD"]]
subset = subset.dropna().reset_index()
subset
# Out:
#       index                  Startup Name           Industry Vertical  \
# 0         0                        BYJU’S                      E-Tech
# 1         1                        Shuttl              Transportation
# 2         2                     Mamaearth                  E-commerce
# 3         3  https://www.wealthbucket.in/                     FinTech
# 4         4                        Fashor         Fashion and Apparel
# ...     ...                           ...                         ...
# 1941   2867                       Icertis   Cloud Enterprise Software
# 1942   2868                        Tracxn  Startup Analytics platform
# 1943   2870                      Tradelab  Financial Markets Software
# 1944   2871                        PiQube   Hiring Analytics platform
# 1945   2872               Travel Triangle   Online Travel Marketplace
#
#      City  Location       InvestmentnType Amount in USD
# 0         Bengaluru  Private Equity Round  20,00,00,000
# ...

# %%
cities = subset.__getattr__("City  Location").unique().tolist()
industries = subset.__getattr__("Industry Vertical").unique().tolist()
investment = subset.__getattr__("InvestmentnType").unique().tolist()
print(cities)
#print(industries)
#print(investment)
# Out:
# ['Bengaluru', 'Gurgaon', 'New Delhi', 'Mumbai', 'Chennai', 'Pune', 'Noida', 'Faridabad', 'San Francisco', 'San Jose,', 'Amritsar', 'Delhi', 'Kormangala', 'Hyderabad', 'Burnsville', 'Menlo Park', 'Gurugram', 'Palo Alto', 'Santa Monica', 'Singapore', 'Taramani', 'Andheri', 'Chembur', 'Haryana', 'New York', 'Karnataka', 'Mumbai/Bengaluru', 'Bhopal', 'Bengaluru and Gurugram', 'India/Singapore', 'Jaipur', 'India/US', 'Nagpur', 'Indore', 'New York, Bengaluru', 'California', 'India', 'Ahemadabad', 'Rourkela', 'Bhubneswar', 'Chandigarh', 'Delhi & Cambridge', 'Kolkata', 'Coimbatore', 'Bangalore', 'Udaipur', 'Ahmedabad', 'Surat', 'Goa', 'Gaya', 'Vadodara', 'Missourie', 'Panaji', 'Gwalior', 'Bangalore/ Bangkok', 'Kerala', 'Lucknow', 'Trivandrum', 'SFO / Bangalore', 'Pune/Seattle', 'Pune / Dubai', 'Bangalore / SFO', 'Varanasi', 'New Delhi / US', 'Mumbai / UK', 'Kanpur', 'Jodhpur', 'Hyderabad/USA', 'Boston', 'Bangalore / Palo Alto', 'Mumbai / NY', 'USA/India', 'Noida / Singapore', 'Belgaum', 'Pun
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Sr No, Date dd/mm/yyyy, Startup Name, Industry Vertical, SubVertical, City  Location, Investors Name, InvestmentnType, Amount in USD, Remarks]
# Index: []
