# %%
import pandas as pd
sd = pd.read_csv("/Users/oliviabliss/desktop/startup_funding.csv")

# %%
sd
# Out:
#                                                                                                                                                                                                                   startup_funding
# Sr No Date dd/mm/yyyy Startup Name                 Industry Vertical SubVertical                           City  Location Investors Name                    InvestmentnType      Amount in USD                            Remarks
# 1     9/1/20          BYJU’S                       E-Tech            E-learning                            Bengaluru      Tiger Global Management           Private Equity Round 20,00,00,000                                 NaN
# 2     13/01/2020      Shuttl                       Transportation    App based shuttle service             Gurgaon        Susquehanna Growth Equity         Series C             80,48,394                                    NaN
# ...
