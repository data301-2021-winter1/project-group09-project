# %% [markdown]
# ## Research question/interests
#
# Which Investment Type provided the most funding in the Finance industry ?

# %%
import pandas as pd
dataset = pd.read_csv("startup_funding_csv.csv")
dataset
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1          9/1/20                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3          9/1/20                     Mamaearth
# 3         4          2/1/20  https://www.wealthbucket.in/
# 4         5          2/1/20                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
#Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# shape of the dataset

dataset.shape
# Out:
# (3044, 10)

# %%
# name of all the columns in the dataset

dataset.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
# I will clean the dataset to see to only keep the columns and data I need for this question

dataset = dataset.copy().drop(['Remarks','Investors Name','City  Location', 'Date dd/mm/yyyy', 'Sr No'], axis=1)

# %%
dataset
# Out:
#                       Startup Name    Industry Vertical  \
# 0                           BYJU’S               E-Tech
# 1                           Shuttl       Transportation
# 2                        Mamaearth           E-commerce
# 3     https://www.wealthbucket.in/              FinTech
# 4                           Fashor  Fashion and Apparel
# ...                            ...                  ...
# 3039                    Printvenue                  NaN
# 3040                      Graphene                  NaN
# 3041                Mad Street Den                  NaN
# 3042                     Simplotel                  NaN
# 3043              couponmachine.in                  NaN
#
#                                 SubVertical       InvestmentnType  \
# 0                                E-learning  Private Equity Round
# 1                 App based shuttle service              Series C
# 2     Retailer of baby and toddler products              Series B
# ...

# %%
dataset = dataset.dropna(axis=0)
dataset
# Out:
#                       Startup Name    Industry Vertical  \
# 0                           BYJU’S               E-Tech
# 1                           Shuttl       Transportation
# 2                        Mamaearth           E-commerce
# 3     https://www.wealthbucket.in/              FinTech
# 4                           Fashor  Fashion and Apparel
# ...                            ...                  ...
# 2098                         Qriyo    Consumer Internet
# 2100                         Aisle    Consumer Internet
# 2101                     FreshMenu    Consumer Internet
# 2102                       Truebil            ECommerce
# 2103                    Rare Media           Technology
#
#                                             SubVertical       InvestmentnType  \
# 0                                            E-learning  Private Equity Round
# 1                             App based shuttle service              Series C
# ...

# %%
seed2 = dataset[dataset["Industry Vertical"] == "Finance"]




seed2
# Out:
#                                            Startup Name Industry Vertical  \
# 13                                               InCred           Finance
# 45                                              Progcap           Finance
# 47                                      Alteria Capital           Finance
# 61                                             RenewBuy           Finance
# 77                                        Avail Finance           Finance
# 78                                             BharatPe           Finance
# 98                                               Kuvera           Finance
# 118   Samunnati Financial Intermediation & Services ...           Finance
# 142                                      InCred Finance           Finance
# 180                                               Finzy           Finance
# 188                                          True North           Finance
# 198                                      Kinara Capital           Finance
# ...

# %%
seed2 = seed2.replace(',','', regex=True)


seed2['Amount in USD'] = pd.to_numeric(seed2['Amount in USD'])



seed2
# Out:
#                                            Startup Name Industry Vertical  \
# 13                                               InCred           Finance
# 45                                              Progcap           Finance
# 47                                      Alteria Capital           Finance
# 61                                             RenewBuy           Finance
# 77                                        Avail Finance           Finance
# 78                                             BharatPe           Finance
# 98                                               Kuvera           Finance
# 118   Samunnati Financial Intermediation & Services ...           Finance
# 142                                      InCred Finance           Finance
# 180                                               Finzy           Finance
# 188                                          True North           Finance
# 198                                      Kinara Capital           Finance
# ...

# %%
sortedf = seed2.sort_values("Amount in USD")

sortedf.replace("Seed/ Angel Funding", "Seed / Angel Funding")

sortedf.replace("Private", "Private Equity")
# Out:
#                                            Startup Name Industry Vertical  \
# 377                                             Fincash           Finance
# 306                                              Mihuru           Finance
# 376                                              happay           Finance
# 257                                             OpenTap           Finance
# 238                                              Nivesh           Finance
# 267                                                Vola           Finance
# 1955                                              Buddy           Finance
# 471                                         Prest Loans           Finance
# 314                                          MyLoanCare           Finance
# 1221                                          GramCover           Finance
# 250                                               Sqqrl           Finance
# 180                                               Finzy           Finance
# ...

# %%
sortedf.to_csv('cleaneddata.csv')

# %%
fig, ax = plt.subplots(figsize=(22, 20))
plt.hist(sortedf['InvestmentnType'], bins=57)
plt.xlabel("Investment Type")
plt.ylabel("Number of Occurences")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(22, 20))
plt.scatter(sortedf['InvestmentnType'], sortedf['Amount in USD'])
plt.xlabel("Investment Type")
plt.ylabel("Number of Occurences")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 15))
seed2.boxplot('Amount in USD')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np



df = (   
    pd.read_csv("startup_funding_csv.csv")
    .rename(columns={"InvestmentnType": "Investment Type"})
    .copy().drop(['Remarks','Investors Name','City  Location', 'Date dd/mm/yyyy', 'Sr No'], axis=1)
    .dropna(axis=0)
    .loc[lambda x: x['Industry Vertical'] == "Finance"]
    .replace(',','', regex=True)
    .astype({"Amount in USD": int})
    .sort_values("Amount in USD")
    .replace("Seed/ Angel Funding", "Seed / Angel Funding")
    .replace("Private", "Private Equity")
    .sort_values("Investment Type")
    
    
)

df
# Out:
#                                            Startup Name Industry Vertical  \
# 13                                               InCred           Finance
# 294                                          AyeFinance           Finance
# 395                                         Lendingkart           Finance
# 118   Samunnati Financial Intermediation & Services ...           Finance
# 1897                                    Veritas Finance           Finance
# 1509                                          NeoGrowth           Finance
# 198                                      Kinara Capital           Finance
# 411                                          OptaCredit           Finance
# 188                                          True North           Finance
# 611                                              SaveBC           Finance
# 514                                           Edelweiss           Finance
# 841                                         Aye Finance           Finance
# ...

# %%
def load_and_process(startup_funding_csv):

    # Method Chain 1 (Load data and drop data)

    df1 = (
          pd.read_csv("startup_funding_csv.csv")
          .rename(columns={"InvestmentnType": "Investment Type"})
          .copy().drop(['Remarks','Investors Name','City  Location', 'Date dd/mm/yyyy', 'Sr No'], axis=1)
          .dropna(axis=0)
      )

    # Method Chain 2 (Cleaning and wrangling)

    df2 = (
          df1
          .loc[lambda x: x['Industry Vertical'] == "Finance"]
          .replace(',','', regex=True)
          .astype({"Amount in USD": int})
          .sort_values("Amount in USD")
          .replace("Seed/ Angel Funding", "Seed / Angel Funding")
          .replace("Private", "Private Equity")
          .sort_values("Investment Type")
          
        
      )
     

    

    return df2

# %%
load_and_process("startup_funding_csv.csv")
# Out:
#                                            Startup Name Industry Vertical  \
# 13                                               InCred           Finance
# 294                                          AyeFinance           Finance
# 395                                         Lendingkart           Finance
# 118   Samunnati Financial Intermediation & Services ...           Finance
# 1897                                    Veritas Finance           Finance
# 1509                                          NeoGrowth           Finance
# 198                                      Kinara Capital           Finance
# 411                                          OptaCredit           Finance
# 188                                          True North           Finance
# 611                                              SaveBC           Finance
# 514                                           Edelweiss           Finance
# 841                                         Aye Finance           Finance
# ...

# %%
load_and_process("startup_funding_csv.csv").describe()
# Out:
#        Amount in USD
# count   5.700000e+01
# mean    3.458663e+07
# std     9.001249e+07
# min     1.500000e+05
# 25%     2.000000e+06
# 50%     6.240000e+06
# 75%     2.300000e+07
# max     6.000000e+08
